# %%
# !pip3 install pandas

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# Load dataset
df = pd.read_csv("data/raw/sales_records.csv")

# Show first 5 rows
df.head()
