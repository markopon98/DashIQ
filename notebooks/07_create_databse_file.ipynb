# %%
import sqlite3
import pandas as pd

# Create database connection
conn = sqlite3.connect("../data/cleaned/dashiq.db")
# Make sure df is defined in a previous cell before executing this cell
# If df is not available, load it here or create it
if 'df' not in dir():
	# Load df from the CSV file
	df = pd.read_csv("../data/cleaned/sales_records_enhanced.csv")
df.to_sql("sales_records_enhanced", conn, if_exists="replace", index=False)
conn.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 10
#       6 # If df is not available, load it here or create it
#       7 if 'df' not in dir():
#       8         # Example: load df from a source
#       9         # df = pd.read_csv("../data/path/to/file.csv")
# ---> 10         raise NameError("df is not defined. Please load or create df in a previous cell.")
#      11 df.to_sql("sales_records_enhanced", conn, if_exists="replace", index=False)
#      12 conn.close()
#
# NameError: df is not defined. Please load or create df in a previous cell.
