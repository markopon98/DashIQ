# %%
import pandas as pd
from pathlib import Path

# %%
notebook_dir = Path.cwd()

data_path = notebook_dir / "../data/raw/sales_records.csv"

data_path = data_path.resolve()
print("Reading from:", data_path)

df = pd.read_csv(data_path)

df.head()
# Out:
# Reading from: C:\Users\Marizze Julliane\OneDrive\Desktop\Mark\DashIQ\data\raw\sales_records.csv
#                          Region           Country  Item Type Sales Channel  \
# 0            Sub-Saharan Africa      South Africa     Fruits       Offline
# 1  Middle East and North Africa           Morocco    Clothes        Online
# 2         Australia and Oceania  Papua New Guinea       Meat       Offline
# 3            Sub-Saharan Africa          Djibouti    Clothes       Offline
# 4                        Europe          Slovakia  Beverages       Offline
#
#   Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 0              M   7/27/2012  443368995   7/28/2012        1593        9.33
# 1              M   9/14/2013  667593514  10/19/2013        4611      109.28
# 2              M   5/15/2015  940995585    6/4/2015         360      421.89
# 3              H   5/17/2017  880811536    7/2/2017         562      109.28
# 4              L  10/26/2016  174590194   12/4/2016        3973       47.45
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit
# 0       6.92       14862.69    11023.56       3839.13
# 1      35.84      503890.08   165258.24     338631.84
# 2     364.69      151880.40   131288.40      20592.00
# 3      35.84       61415.36    20142.08      41273.28
# 4      31.79      188518.85   126301.67      62217.18

# %%
# Count exact duplicate rows
duplicate_count = df.duplicated().sum()
duplicate_count
# Out:
# np.int64(0)

# %%
# Show duplicate rows
duplicate_rows = df[df.duplicated()]
duplicate_rows.head()
# Out:
#                                    Region              Country      Item Type  \
# 747904  Central America and the Caribbean  Trinidad and Tobago  Personal Care
# 747907                 Sub-Saharan Africa             Djibouti        Clothes
# 747908                 Sub-Saharan Africa             Tanzania      Cosmetics
# 747909              Australia and Oceania            Australia      Household
# 747913                             Europe              Denmark           Meat
#
#        Sales Channel Order Priority Order Date   Order ID   Ship Date  \
# 747904       Offline              M  4/20/2015  370419776    5/4/2015
# 747907       Offline              H  5/27/2010  667237317   6/27/2010
# 747908        Online              L  9/16/2016  214140975  10/19/2016
# 747909       Offline              L  1/12/2011  222868669   2/23/2011
# 747913       Offline              C  9/24/2012  244183862  10/28/2012
#
#         Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  \
# 747904        4298       81.73      56.67      351275.54   243567.66
# 747907        9204      109.28      35.84     1005813.12   329871.36
# 747908        7928      437.20     263.33     3466121.60  2087680.24
# 747909         647      668.27     502.54      432370.69   325143.38
# 747913        8286      421.89     364.69     3495780.54  3021821.34
#
#         Total Profit
# 747904     107707.88
# 747907     675941.76
# 747908    1378441.36
# 747909     107227.31
# 747913     473959.20

# %%
# Count duplicate Order IDs
duplicate_order_ids = df["Order ID"].duplicated().sum()
duplicate_order_ids
# Out:
# np.int64(100000)

# %%
# Show rows with repeated Order IDs (For Removal)
repeated_orders = df[df["Order ID"].duplicated(keep=False)].sort_values("Order ID")
repeated_orders.head(10)
# Out:
#                     Region        Country   Item Type Sales Channel  \
# 782778              Europe        Ukraine   Cosmetics       Offline
# 434874              Europe        Ukraine   Cosmetics       Offline
# 423998                Asia       Malaysia   Household       Offline
# 771902                Asia       Malaysia   Household       Offline
# 432733  Sub-Saharan Africa         Angola  Vegetables       Offline
# 780637  Sub-Saharan Africa         Angola  Vegetables       Offline
# 474000              Europe         Serbia        Meat        Online
# 821904              Europe         Serbia        Meat        Online
# 759386  Sub-Saharan Africa  Guinea-Bissau  Vegetables        Online
# 411482  Sub-Saharan Africa  Guinea-Bissau  Vegetables        Online
#
#        Order Priority  Order Date   Order ID   Ship Date  Units Sold  \
# 782778              H   12/1/2014  100016200  12/28/2014        5871
# 434874              H   12/1/2014  100016200  12/28/2014        5871
# 423998              L   1/17/2016  100017917   1/27/2016        6379
# 771902              L   1/18/2016  100017917   1/28/2016        6379
# 432733              L  10/24/2010  100024354   12/9/2010        8284
# 780637              L  10/24/2010  100024354   12/9/2010        8284
# 474000              L    9/7/2012  100053107   9/16/2012        6793
# 821904              L    9/7/2012  100053107   9/16/2012        6793
# 759386              M   8/22/2014  100084865   10/5/2014        6190
# 411482              M   8/22/2014  100084865   10/5/2014        6190
#
#         Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit  \
# 782778      437.20     263.33     2566801.20  1546010.43    1020790.77
# 434874      437.20     263.33     2566801.20  1546010.43    1020790.77
# 423998      668.27     502.54     4262894.33  3205702.66    1057191.67
# 771902      668.27     502.54     4262894.33  3205702.66    1057191.67
# 432733      154.06      90.93     1276233.04   753264.12     522968.92
# 780637      154.06      90.93     1276233.04   753264.12     522968.92
# 474000      421.89     364.69     2865898.77  2477339.17     388559.60
# 821904      421.89     364.69     2865898.77  2477339.17     388559.60
# 759386      154.06      90.93      953631.40   562856.70     390774.70
# 411482      154.06      90.93      953631.40   562856.70     390774.70
#
#         is_duplicate
# 782778          True
# 434874         False
# 423998         False
# 771902         False
# 432733         False
# 780637          True
# 474000         False
# 821904          True
# 759386          True
# 411482         False

# %%
# Create a flag for duplicate
# Mark exact duplicate rows
df["is_duplicate"] = df.duplicated()

# Count flagged duplicates
df["is_duplicate"].value_counts()
# Out:
# is_duplicate
# False    949991
# True      50009
# Name: count, dtype: int64

# %%
# Marked for removal
rows_marked_for_removal = df[df["is_duplicate"] == True]
rows_marked_for_removal.head()
# Out:
# Empty DataFrame
# Columns: [Region, Country, Item Type, Sales Channel, Order Priority, Order Date, Order ID, Ship Date, Units Sold, Unit Price, Unit Cost, Total Revenue, Total Cost, Total Profit, is_duplicate]
# Index: []

# %%
# Saving duplicate rows for audit trail
output_path = data_path.parent / "duplicate_rows_review.csv"
rows_marked_for_removal.to_csv(output_path, index=False)
